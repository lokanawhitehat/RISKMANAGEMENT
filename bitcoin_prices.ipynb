# %%
# !pip install yahoofinancials

# %%
# https://towardsdatascience.com/a-comprehensive-guide-to-downloading-stock-prices-in-python-2cd93ff821d4
# https://pypi.org/project/yfinance/
import sys

# !{sys.executable} --version
# !{sys.executable} -m pip install yfinance
# !{sys.executable} -m pip install yahoofinancials

import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
import matplotlib.pyplot as plt
from IPython.display import display

# %matplotlib inline
# Out:
# Python 3.9.18

# %% [markdown]
# # download Bitcoin price history

# %%
btc_df = yf.download('BTC-USD', 
                      start='2015-01-01', 
                      end='2025-01-22', 
                      progress=False, auto_adjust=True)
display(btc_df.head())
display(btc_df.tail())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker         BTC-USD     BTC-USD     BTC-USD     BTC-USD   BTC-USD
# Date
# 2015-01-01  314.248993  320.434998  314.002991  320.434998   8036550
# 2015-01-02  315.032013  315.838989  313.565002  314.079010   7860650
# 2015-01-03  281.082001  315.149994  281.082001  314.846008  33054400
# 2015-01-04  264.195007  287.230011  257.612000  281.145996  55629100
# 2015-01-05  274.473999  278.341003  265.084015  265.084015  43962800
# Price               Close           High            Low           Open  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2025-01-17  104462.039062  105884.226562   99948.906250  100025.765625
# 2025-01-18  104408.070312  104913.203125  102226.617188  104124.953125
# 2025-01-19  101089.609375  106299.796875   99570.531250  104411.289062
# 2025-01-20  102016.664062  109114.882812   99471.359375  101083.750000
# 2025-01-21  106463.890625  107145.828125  100351.132812  102130.648438
#
# Price             Volume
# Ticker           BTC-USD
# Date
# 2025-01-17   71888972663
# 2025-01-18   50445655726
# 2025-01-19   76789928525
# 2025-01-20  126279678351
# 2025-01-21   88758861824

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,6))
plt.plot(btc_df['Close']['2022-01-20':], linewidth=3)
plt.title("Bitcoin price in USD", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.show()
